# %% [markdown]
# ### Classification Project
# ### Team 06
# ### Members
#
# * 202418006
# * 202418008
# * 202418012
# * 202418045

# %% [markdown]
# ### Problem Formulation

# %% [markdown]
# This project aims to apply Clustering based on features such as Energy, loudness and danceability. These insights in future will help the creation of personalized music recommendations tailored to individual emotional needs, enhancing the effectiveness of music-based interventions.

# %%
# !pip install kneed
# Out:
# Requirement already satisfied: kneed in /usr/local/lib/python3.10/dist-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.13.1)

# %% [markdown]
# ### Importing libraries and tools

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from kneed import KneeLocator
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ## Data Preprocessing

# %%
def prepare_df(csv_file):
    df = pd.read_csv(csv_file)
    df_main = df.copy()
    df_main.columns = [x.strip() for x in df_main.columns]
    df_main = df_main.set_index(['name','artist'])
    df_main = df_main.drop(columns=['key','duration_ms','type', 'id', 'html','Unnamed: 0'])
    return df_main

# %%
df = prepare_df('/content/df_audio_features_5000.xls')

# %%
df.shape
# Out:
# (5235, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5235 entries, ('Se Eu Quiser Falar Com Deus                                                                                                                                                      ', 'Gilberto Gil                                    ') to ('Ravel: Boléro, M. 81                                                                                                                                                           ', 'Maurice Ravel                                   ')
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      5235 non-null   float64
#  1   energy            5235 non-null   float64
#  2   loudness          5235 non-null   float64
#  3   mode              5235 non-null   int64
#  4   speechiness       5235 non-null   float64
#  5   acousticness      5235 non-null   float64
#  6   instrumentalness  5235 non-null   float64
#  7   liveness          5235 non-null   float64
#  8   valence           5235 non-null   float64
#  9   tempo             5235 non-null   float64
#  10  time_signature    5235 non-null   int64
# dtypes: float64(9), int64(2)
# memory usage: 720.2+ KB

# %% [markdown]
# ### Exploratory Data Analysis

# %%
columns = ['danceability', 'energy', 'loudness', 'mode', 'speechiness',
           'acousticness', 'instrumentalness', 'liveness', 'valence',
           'tempo']

n_rows = 5
n_cols = 2

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15))
axes = axes.flatten()

for i, col in enumerate(columns):
    if i < len(columns):
        df.boxplot(column=col, ax=axes[i], color='#00BFA5', patch_artist=True,
                   boxprops=dict(facecolor='#00BFA5', color='#1C1C1C'),
                   whiskerprops=dict(color='#1C1C1C'),
                   capprops=dict(color='#1C1C1C'),
                   flierprops=dict(markerfacecolor='#FF5733', marker='o', markersize=7),
                   medianprops=dict(color='#C70039', linewidth=2))
        axes[i].set_title(col, fontsize=16, fontweight='bold', color='#1C1C1C')
        axes[i].tick_params(axis='both', labelsize=12, colors='#1C1C1C')
        axes[i].set_xlabel('', fontsize=12, color='#1C1C1C')
        axes[i].set_ylabel('Value', fontsize=12, color='#1C1C1C')
        axes[i].grid(True, linestyle='--', alpha=0.7)
    else:
        axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Features such as danceability, energy, and mode show less variability, indicating consistency across tracks.
# Loudness, speechiness, and liveness display significant outliers, which could represent niche or uncommon tracks.
# The data indicates a mix of studio-recorded tracks with occasional live or experimental tracks (high instrumentalness or liveness).

# %% [markdown]
# Seperating data for minmax Scaler

# %%
df_minmax = df[['danceability', 'mode','acousticness', 'instrumentalness','energy','valence']]

# %% [markdown]
# Seprating data for robust scaler

# %%
df_robust = df[list(set(df.columns) - set(df_minmax.columns))]

# %%
df_robust
# Out:
#                                                                                                        tempo  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      110.376
# Saudade De Bahia                               ... Antônio Carlos Jobim                              125.039
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                   93.698
# Mulher Eu Sei                                  ... Chico César                                       106.802
# Rosa Morena                                    ... Kurt Elling                                       120.941
# ...                                                                                                      ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... Pyotr Ilyich Tchaikovsky                           87.906
# Winter Fragments pour ensemble instrumental, so... Tristan Murail                                     83.134
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... Arnold Schoenberg                                  71.573
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... Antonín Dvořák                                     67.109
# Ravel: Boléro, M. 81                           ... Maurice Ravel                                      64.120
#
#                                                                                                      liveness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                        0.9750
# Saudade De Bahia                               ... Antônio Carlos Jobim                                0.1070
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                    0.1240
# Mulher Eu Sei                                  ... Chico César                                         0.3860
# Rosa Morena                                    ... Kurt Elling                                         0.1040
# ...                                                                                                       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... Pyotr Ilyich Tchaikovsky                            0.0832
# Winter Fragments pour ensemble instrumental, so... Tristan Murail                                      0.0694
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... Arnold Schoenberg                                   0.0772
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... Antonín Dvořák                                      0.1110
# Ravel: Boléro, M. 81                           ... Maurice Ravel                                       0.2840
#
#                                                                                                      loudness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                       -13.141
# Saudade De Bahia                               ... Antônio Carlos Jobim                               -12.646
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                   -11.048
# Mulher Eu Sei                                  ... Chico César                                        -18.115
# Rosa Morena                                    ... Kurt Elling                                        -19.807
# ...                                                                                                       ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... Pyotr Ilyich Tchaikovsky                           -23.390
# Winter Fragments pour ensemble instrumental, so... Tristan Murail                                     -21.873
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... Arnold Schoenberg                                  -42.959
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... Antonín Dvořák                                     -29.443
# Ravel: Boléro, M. 81                           ... Maurice Ravel                                      -24.568
#
#                                                                                                      time_signature  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                                   4
# Saudade De Bahia                               ... Antônio Carlos Jobim                                           4
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                               4
# Mulher Eu Sei                                  ... Chico César                                                    4
# Rosa Morena                                    ... Kurt Elling                                                    4
# ...                                                                                                             ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... Pyotr Ilyich Tchaikovsky                                       4
# Winter Fragments pour ensemble instrumental, so... Tristan Murail                                                 4
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... Arnold Schoenberg                                              3
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... Antonín Dvořák                                                 4
# Ravel: Boléro, M. 81                           ... Maurice Ravel                                                  3
#
#                                                                                                      speechiness
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                           0.0705
# Saudade De Bahia                               ... Antônio Carlos Jobim                                   0.0346
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                       0.3470
# Mulher Eu Sei                                  ... Chico César                                            0.0471
# Rosa Morena                                    ... Kurt Elling                                            0.0380
# ...                                                                                                          ...
# 1812 Festival Overture, Op. 49: 1812 Overture, ... Pyotr Ilyich Tchaikovsky                               0.0473
# Winter Fragments pour ensemble instrumental, so... Tristan Murail                                         0.0442
# Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... Arnold Schoenberg                                      0.0434
# Serenade For Strings In E, Op.22, B. 52: 1. Mod... Antonín Dvořák                                         0.0419
# Ravel: Boléro, M. 81                           ... Maurice Ravel                                          0.0323
#
# [5235 rows x 5 columns]

# %% [markdown]
# Transforming data

# %%
def preprocessing_minmax(df):
    transformer = MinMaxScaler()
    transformer.fit(df)
    normal_df = transformer.transform(df)
    normal_df = pd.DataFrame(normal_df, index=df.index, columns=df.columns)
    return normal_df

# %%
minmax_df = preprocessing_minmax(df_minmax)

# %%
def preprocessing_robust(df):
    transformer = RobustScaler()
    transformer.fit(df)
    robust_df = transformer.transform(df)
    robust_df = pd.DataFrame(robust_df, index=df.index, columns=df.columns)
    return robust_df

# %%
robust_df = preprocessing_robust(df_robust)

# %% [markdown]
# storing prepared dataframe

# %%
scaled_df = pd.concat([minmax_df, robust_df], axis=1)

# %%
scaled_df.head()
# Out:
#                                                                                                      danceability  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                          0.680455
# Saudade De Bahia                               ... Antônio Carlos Jobim                                  0.767322
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                      0.880041
# Mulher Eu Sei                                  ... Chico César                                           0.729059
# Rosa Morena                                    ... Kurt Elling                                           0.673216
#
#                                                                                                      mode  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                       0.0
# Saudade De Bahia                               ... Antônio Carlos Jobim                               1.0
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                   1.0
# Mulher Eu Sei                                  ... Chico César                                        1.0
# Rosa Morena                                    ... Kurt Elling                                        1.0
#
#                                                                                                      acousticness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                          0.696787
# Saudade De Bahia                               ... Antônio Carlos Jobim                                  0.217871
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                      0.454819
# Mulher Eu Sei                                  ... Chico César                                           0.882530
# Rosa Morena                                    ... Kurt Elling                                           0.919679
#
#                                                                                                      instrumentalness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                              0.000060
# Saudade De Bahia                               ... Antônio Carlos Jobim                                      0.000002
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                          0.000064
# Mulher Eu Sei                                  ... Chico César                                               0.000041
# Rosa Morena                                    ... Kurt Elling                                               0.000348
#
#                                                                                                      energy  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      0.2590
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.3990
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                  0.7300
# Mulher Eu Sei                                  ... Chico César                                       0.0502
# Rosa Morena                                    ... Kurt Elling                                       0.1190
#
#                                                                                                       valence  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      0.310660
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.703553
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                  0.918782
# Mulher Eu Sei                                  ... Chico César                                       0.531980
# Rosa Morena                                    ... Kurt Elling                                       0.408122
#
#                                                                                                         tempo  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                     -0.232633
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.154816
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.673325
# Mulher Eu Sei                                  ... Chico César                                      -0.327071
# Rosa Morena                                    ... Kurt Elling                                       0.046532
#
#                                                                                                      liveness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      5.882353
# Saudade De Bahia                               ... Antônio Carlos Jobim                             -0.124567
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.006920
# Mulher Eu Sei                                  ... Chico César                                       1.806228
# Rosa Morena                                    ... Kurt Elling                                      -0.145329
#
#                                                                                                      loudness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                     -0.955541
# Saudade De Bahia                               ... Antônio Carlos Jobim                             -0.874033
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.610901
# Mulher Eu Sei                                  ... Chico César                                      -1.774576
# Rosa Morena                                    ... Kurt Elling                                      -2.053186
#
#                                                                                                      time_signature  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                                 0.0
# Saudade De Bahia                               ... Antônio Carlos Jobim                                         0.0
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                             0.0
# Mulher Eu Sei                                  ... Chico César                                                  0.0
# Rosa Morena                                    ... Kurt Elling                                                  0.0
#
#                                                                                                      speechiness
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                         0.246438
# Saudade De Bahia                               ... Antônio Carlos Jobim                                -0.355407
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                     4.881811
# Mulher Eu Sei                                  ... Chico César                                         -0.145851
# Rosa Morena                                    ... Kurt Elling                                         -0.298407

# %%
eda_df = scaled_df.copy()

# %% [markdown]
# Appling PCA

# %%
pca = PCA(n_components=0.95)


pca_result = pca.fit_transform(scaled_df)


n_components = pca.n_components_

pca_df = pd.DataFrame(data=pca_result, columns=[f'PC{i+1}' for i in range(n_components)])

print(pca_df)

print(f"Explained variance ratio: {pca.explained_variance_ratio_}")
print(f"Total explained variance: {sum(pca.explained_variance_ratio_):.2f}")
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0     0.792519  3.365776  4.283616 -0.003536 -0.667859  0.487113 -0.322203
# 1    -1.003510 -0.018348 -0.405229  0.225674  0.315072  0.418330 -0.212045
# 2     2.915858 -3.121311  1.180639 -0.519300  0.416211  0.605100 -0.488637
# 3    -1.091066  0.599960  1.765466  0.045788  0.306466  0.695292 -0.412363
# 4    -1.815678 -0.650430  0.430747  0.442595  0.296619  0.650706 -0.328808
# ...        ...       ...       ...       ...       ...       ...       ...
# 5230 -2.294140 -1.278825  1.014691 -0.169538  0.319055  0.167072  0.299913
# 5231 -2.194202 -1.193293  0.770640 -0.375583  0.328568  0.212455  0.174477
# 5232 -4.326417 -2.685923  2.976310  0.245391  0.306434 -0.272170 -0.149767
# 5233 -2.931629 -1.549127  1.766928 -0.479080  0.318964  0.355940  0.216099
# 5234 -2.318004 -0.366704  2.147565 -0.697417  0.341681 -0.382592 -0.546205
#
# [5235 rows x 7 columns]
# Explained variance ratio: [0.34745924 0.21531147 0.19320811 0.10462374 0.0454637  0.03592742
#  0.02970648]
# Total explained variance: 0.97

# %%
scaled_df = pca_df

# %% [markdown]
# Computes inertia values for KMeans clustering with cluster counts from 2 to 50.

# %%
def find_best_clusters(scaled_df):
    inertia_list = []
    K = range(2, 51)
    for k in K:
        myKMeans = KMeans(n_clusters=k, init = 'k-means++', random_state=42)
        myKMeans.fit(scaled_df)
        inertia_list.append(myKMeans.inertia_)
    return inertia_list

# %%
inertia_list = find_best_clusters(scaled_df)

# %% [markdown]
# Generates an elbow plot for KMeans inertia values, identifies the optimal number of clusters using the knee point, and displays the result.

# %%
def generate_elbow_plot(inertia_list):
    plt.plot(inertia_list, 'o-', color='blue')
    plt.xlabel("Number of Clusters (K)")
    plt.ylabel("Cluster Inertia")
    plt.title("Elbow Plot of KMeans")

    knee_locator = KneeLocator(range(1, len(inertia_list) + 1), inertia_list, curve='convex', direction='decreasing')
    optimal_k = knee_locator.elbow

    plt.axvline(x=optimal_k, color='red', linestyle='--')
    plt.text(optimal_k + 0.5, inertia_list[optimal_k-1], f'Optimal K={optimal_k}', color='red', fontsize=12)

    plt.show()
    print(f"Optimal K: {optimal_k}")

# %%
generate_elbow_plot(inertia_list)
# Out:
# Optimal K: 8

# %% [markdown]
# Applying KMeans clustering to the scaled data, assigns cluster labels to each data point, and returns the updated DataFrame.

# %%
def clustering_model(scaled_df, n_clusters):
    clustering = KMeans(n_clusters, init='k-means++', random_state=42)
    clustering.fit(scaled_df)
    scaled_df['cluster'] = clustering.predict(scaled_df)
    return scaled_df

# %%
cm_df = clustering_model(scaled_df, 8)

# %%
cm_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.792519  3.365776  4.283616 -0.003536 -0.667859  0.487113 -0.322203
# 1 -1.003510 -0.018348 -0.405229  0.225674  0.315072  0.418330 -0.212045
# 2  2.915858 -3.121311  1.180639 -0.519300  0.416211  0.605100 -0.488637
# 3 -1.091066  0.599960  1.765466  0.045788  0.306466  0.695292 -0.412363
# 4 -1.815678 -0.650430  0.430747  0.442595  0.296619  0.650706 -0.328808
#
#    cluster
# 0        5
# 1        6
# 2        7
# 3        6
# 4        6

# %%
def clustering_model(scaled_df, n_clusters):
    clustering = KMeans(n_clusters, init='k-means++', random_state=42)
    clustering.fit(scaled_df)
    scaled_df['elbow_clusters'] = clustering.predict(scaled_df)
    return scaled_df

# %%
final_df = clustering_model(scaled_df, 15)

# %%
final_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.792519  3.365776  4.283616 -0.003536 -0.667859  0.487113 -0.322203
# 1 -1.003510 -0.018348 -0.405229  0.225674  0.315072  0.418330 -0.212045
# 2  2.915858 -3.121311  1.180639 -0.519300  0.416211  0.605100 -0.488637
# 3 -1.091066  0.599960  1.765466  0.045788  0.306466  0.695292 -0.412363
# 4 -1.815678 -0.650430  0.430747  0.442595  0.296619  0.650706 -0.328808
#
#    cluster  elbow_clusters
# 0        5               8
# 1        6               6
# 2        7              13
# 3        6               2
# 4        6               6

# %% [markdown]
# ### Clustering

# %% [markdown]
# ## K-means Clustering

# %%
def find_sil_scores(fianl_df, n_clusters):
    silhouette_list = []
    K = range(2, n_clusters)
    for k in K:
        myKMeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
        myKMeans.fit(final_df)
        sil_score = silhouette_score(final_df, myKMeans.labels_)
        silhouette_list.append(sil_score)
    return silhouette_list

# %%
sil_list = find_sil_scores(final_df, 25)

# %%
for i in range(0,23):
    print(f"n_clusters:{i+2}, Silhouette Score: {sil_list[i]}")
# Out:
# n_clusters:2, Silhouette Score: 0.3430447339115099
# n_clusters:3, Silhouette Score: 0.39140704332297704
# n_clusters:4, Silhouette Score: 0.36179540228947443
# n_clusters:5, Silhouette Score: 0.36317127513732916
# n_clusters:6, Silhouette Score: 0.333383612889849
# n_clusters:7, Silhouette Score: 0.36043735197279747
# n_clusters:8, Silhouette Score: 0.35233412608570663
# n_clusters:9, Silhouette Score: 0.347741233794456
# n_clusters:10, Silhouette Score: 0.33241898110523754
# n_clusters:11, Silhouette Score: 0.35223109371424255
# n_clusters:12, Silhouette Score: 0.3229005378194499
# n_clusters:13, Silhouette Score: 0.31874929632985705
# n_clusters:14, Silhouette Score: 0.312221289080798
# n_clusters:15, Silhouette Score: 0.2396962738651277
# n_clusters:16, Silhouette Score: 0.22769615871874097
# n_clusters:17, Silhouette Score: 0.21067614242996388
# n_clusters:18, Silhouette Score: 0.21029237885072558
# n_clusters:19, Silhouette Score: 0.18640791534261547
# n_clusters:20, Silhouette Score: 0.1856747827614036
# n_clusters:21, Silhouette Score: 0.20580009131528074
# n_clusters:22, Silhouette Score: 0.20124321448029706
# n_clusters:23, Silhouette Score: 0.19881053265660517
# n_clusters:24, Silhouette Score: 0.19395404199643693

# %%
myKMeans = KMeans(n_clusters=12, init='k-means++', random_state=42)
myKMeans.fit(final_df)

sil_score = silhouette_score(final_df, myKMeans.labels_)
db_score = davies_bouldin_score(final_df, myKMeans.labels_)
ch_score = calinski_harabasz_score(final_df, myKMeans.labels_)

print("K-Means Performance:")
print("Number of Clusters: 12")
print(f"Silhouette Score: {sil_score}")
print(f"Calinski-Harabasz Score: {ch_score}")
print(f"Davies-Bouldin Score: {db_score}")
# Out:
# K-Means Performance:
# Number of Clusters: 12
# Silhouette Score: 0.608600325002487
# Calinski-Harabasz Score: 6440.008409536369
# Davies-Bouldin Score: 0.5541955555081123

# %% [markdown]
# ## Agglomerative Clustering

# %%
def agg_tuning(data, cluster_range, linkage_methods):
    results = []

    for linkage in linkage_methods:
        for n_clusters in cluster_range:
            agg_clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
            labels = agg_clustering.fit_predict(data)

            if len(set(labels)) > 1:
                silhouette = silhouette_score(data, labels)
                davies_bouldin = davies_bouldin_score(data, labels)
                calinski_harabasz = calinski_harabasz_score(data, labels)
                results.append((n_clusters, linkage, silhouette, davies_bouldin, calinski_harabasz))
            else:
                results.append((n_clusters, linkage, None, None, None))

    best_result = max(results, key=lambda x: x[2] if x[2] is not None else -1)

    return results, best_result
cluster_range = range(15, 25)
linkage_methods = ['ward', 'complete', 'average', 'single']
results, best_result = agg_tuning(final_df, cluster_range, linkage_methods)
print("Agglomerative Clustering Tuning Results:")
for n_clusters, linkage, silhouette, davies_bouldin, calinski_harabasz in results:
    print(f"Clusters: {n_clusters}, Linkage: {linkage}, "
          f"Silhouette Score: {silhouette}, "
          f"Davies-Bouldin Index: {davies_bouldin}, "
          f"Calinski-Harabasz Index: {calinski_harabasz}")
best_clusters, best_linkage, best_silhouette, best_db, best_ch = best_result
print("\nBest results for Agglomerative Clustering:")
print(f"Clusters: {best_clusters}, Linkage: {best_linkage}")
print(f"Silhouette Score: {best_silhouette}")
print(f"Davies-Bouldin Index: {best_db}")
print(f"Calinski-Harabasz Index: {best_ch}")
# Out:
# Agglomerative Clustering Tuning Results:
# Clusters: 15, Linkage: ward, Silhouette Score: 0.5403395846546617, Davies-Bouldin Index: 0.8979757829559377, Calinski-Harabasz Index: 7536.400390005513
# Clusters: 16, Linkage: ward, Silhouette Score: 0.5331550377030582, Davies-Bouldin Index: 0.98502457590851, Calinski-Harabasz Index: 7200.935632568013
# Clusters: 17, Linkage: ward, Silhouette Score: 0.4197902799830487, Davies-Bouldin Index: 1.1361552708131561, Calinski-Harabasz Index: 6885.7153088948035
# Clusters: 18, Linkage: ward, Silhouette Score: 0.4030910320075842, Davies-Bouldin Index: 1.2085677038534515, Calinski-Harabasz Index: 6608.852812619914
# Clusters: 19, Linkage: ward, Silhouette Score: 0.4038323468312374, Davies-Bouldin Index: 1.2046147510176501, Calinski-Harabasz Index: 6359.733376797137
# Clusters: 20, Linkage: ward, Silhouette Score: 0.3647592509200973, Davies-Bouldin Index: 1.285142454005366, Calinski-Harabasz Index: 6131.525683902519
# Clusters: 21, Linkage: ward, Silhouette Score: 0.3289581413279393, Davies-Bouldin Index: 1.4484625907371926, Calinski-Harabasz Index: 5913.942274717292
# Clusters: 22, Linkage: ward, Silhouette Score: 0.3297015389542396, Davies-Bouldin Index: 1.433514606068486, Calinski-Harabasz Index: 5714.5365590473
# Clusters: 23, Linkage: ward, Silhouette Score: 0.32781664575103586, Davies-Bouldin Index: 1.4012325629841778, Calinski-Harabasz Index: 5528.876548299666
# Clusters: 24, Linkage: ward, Silhouette Score: 0.32637136752096824, Davies-Bouldin Index: 1.4391594084139896, Calinski-Harabasz Index: 5357.188029190298
# Clusters: 15, Linkage: complete, Silhouette Score: 0.6052990534609087, Davies-Bouldin Index: 0.6213658043272017, Calinski-Harabasz Index: 5359.982293705616
# Clusters: 16, Linkage: complete, Silhouette Score: 0.6025460934187427, Davies-Bouldin Index: 0.6415047995146653, Calinski-Harabasz Index: 5020.073803471061
# Clusters: 17, Linkage: complete, Silhouette Score: 0.5843539514008772, Davies-Bouldin Index: 0.668522402916711, Calinski-Harabasz Index: 5723.262593266084
# Clusters: 18, Linkage: complete, Silhouette Score: 0.565490424096577, Davies-Bouldin Index: 0.7796645121010966, Calinski-Harabasz Index: 5466.1911885282425
# Clusters: 19, Linkage: complete, Silhouette Score: 0.5436381541444041, Davies-Bouldin Index: 0.8100085551486963, Calinski-Harabasz Index: 5922.4334603264415
# Clusters: 20, Linkage: complete, Silhouette Score: 0.5366029283292406, Davies-Bouldin Index: 0.8867296037855603, Calinski-Harabasz Index: 5725.465446998916
# Clusters: 21, Linkage: complete, Silhouette Score: 0.5374798884231793, Davies-Bouldin Index: 0.8791387200040387, Calinski-Harabasz Index: 5508.179428772355
# Clusters: 22, Linkage: complete, Silhouette Score: 0.5385157570436387, Davies-Bouldin Index: 0.8795747642292869, Calinski-Harabasz Index: 5310.787421221248
# Clusters: 23, Linkage: complete, Silhouette Score: 0.5375828357812045, Davies-Bouldin Index: 0.8988378469720368, Calinski-Harabasz Index: 5096.113273486634
# Clusters: 24, Linkage: complete, Silhouette Score: 0.5378604087648414, Davies-Bouldin Index: 0.8837984024480496, Calinski-Harabasz Index: 4899.903284040612
# Clusters: 15, Linkage: average, Silhouette Score: 0.6033271892291998, Davies-Bouldin Index: 0.5596326854567216, Calinski-Harabasz Index: 5364.586492292707
# Clusters: 16, Linkage: average, Silhouette Score: 0.6005742291870338, Davies-Bouldin Index: 0.5865943971832088, Calinski-Harabasz Index: 5024.399821127311
# Clusters: 17, Linkage: average, Silhouette Score: 0.5954237373311437, Davies-Bouldin Index: 0.6236766458372047, Calinski-Harabasz Index: 4718.830422277326
# Clusters: 18, Linkage: average, Silhouette Score: 0.5685629575862254, Davies-Bouldin Index: 0.665514054612887, Calinski-Harabasz Index: 4470.004985741606
# Clusters: 19, Linkage: average, Silhouette Score: 0.5464027531210606, Davies-Bouldin Index: 0.7017883791813838, Calinski-Harabasz Index: 4255.113242684936
# Clusters: 20, Linkage: average, Silhouette Score: 0.5448664569651982, Davies-Bouldin Index: 0.735328424220412, Calinski-Harabasz Index: 4050.079372715662
# Clusters: 21, Linkage: average, Silhouette Score: 0.5437434671659621, Davies-Bouldin Index: 0.7539081905114835, Calinski-Harabasz Index: 3902.038672659044
# Clusters: 22, Linkage: average, Silhouette Score: 0.53492308683624, Davies-Bouldin Index: 0.7547898419465061, Calinski-Harabasz Index: 3729.2655405490746
# Clusters: 23, Linkage: average, Silhouette Score: 0.5265938773807086, Davies-Bouldin Index: 0.7473140478278376, Calinski-Harabasz Index: 3565.9211149242037
# Clusters: 24, Linkage: average, Silhouette Score: 0.5034638739633814, Davies-Bouldin Index: 0.7367961565454609, Calinski-Harabasz Index: 3423.702558178001
# Clusters: 15, Linkage: single, Silhouette Score: 0.600668571018858, Davies-Bouldin Index: 0.5239684593830702, Calinski-Harabasz Index: 5087.768066531385
# Clusters: 16, Linkage: single, Silhouette Score: 0.6013292291613163, Davies-Bouldin Index: 0.528700126606138, Calinski-Harabasz Index: 4966.134495185167
# Clusters: 17, Linkage: single, Silhouette Score: 0.6005640599679544, Davies-Bouldin Index: 0.518876114121722, Calinski-Harabasz Index: 4666.334631815155
# Clusters: 18, Linkage: single, Silhouette Score: 0.5961088730521253, Davies-Bouldin Index: 0.5074564847633161, Calinski-Harabasz Index: 4399.013038179425
# Clusters: 19, Linkage: single, Silhouette Score: 0.5873470955664674, Davies-Bouldin Index: 0.5111936283132749, Calinski-Harabasz Index: 4161.501184018719
# Clusters: 20, Linkage: single, Silhouette Score: 0.5656349715538412, Davies-Bouldin Index: 0.5532739040469683, Calinski-Harabasz Index: 3973.3097056389006
# Clusters: 21, Linkage: single, Silhouette Score: 0.5644788571284927, Davies-Bouldin Index: 0.5514166366270907, Calinski-Harabasz Index: 3776.429238579455
# Clusters: 22, Linkage: single, Silhouette Score: 0.5625372217520932, Davies-Bouldin Index: 0.5484043541683867, Calinski-Harabasz Index: 3600.117168521481
# Clusters: 23, Linkage: single, Silhouette Score: 0.558942925323171, Davies-Bouldin Index: 0.5409960760433311, Calinski-Harabasz Index: 3439.470561199564
# Clusters: 24, Linkage: single, Silhouette Score: 0.5276716494804115, Davies-Bouldin Index: 0.5497299290342458, Calinski-Harabasz Index: 3296.3398805084535
#
# Best results for Agglomerative Clustering:
# Clusters: 15, Linkage: complete
# Silhouette Score: 0.6052990534609087
# Davies-Bouldin Index: 0.6213658043272017
# Calinski-Harabasz Index: 5359.982293705616

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
def plot_dendrogram(data, method):
    Z = linkage(data, method=method)
    plt.figure(figsize=(10, 7))
    plt.title(f"Dendrogram (Linkage Method: {method})")
    dendrogram(Z)
    plt.xlabel("Data Points")
    plt.ylabel("Distance")
    plt.show()
plot_dendrogram(final_df, method='ward')

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN(eps=1.5, min_samples=15)
dbscan_labels = dbscan.fit_predict(final_df)

final_df['dbscan_labels'] = dbscan_labels

cluster_counts = final_df['dbscan_labels'].value_counts()
print("\nDBSCAN Cluster Counts:\n", cluster_counts)

noise_count = cluster_counts.get(-1, 0)
total_samples = len(final_df)
noise_proportion = noise_count / total_samples
print(f"\nNoise Proportion (-1 class): {noise_count}/{total_samples} ({noise_proportion:.2%})")
# Out:
# DBSCAN Cluster Counts:
#  dbscan_labels
#  5     1244
#  4     1028
#  3      896
#  6      489
#  2      461
#  0      314
#  7      205
#  8      173
#  1      165
# -1      114
#  11      89
#  9       41
#  10      16
# Name: count, dtype: int64
#
# Noise Proportion (-1 class): 114/5235 (2.18%)

# %%
sns.countplot(x='dbscan_labels', data=final_df)
plt.title("Cluster Distribution - DBSCAN")
plt.xlabel("Cluster")
plt.ylabel("Count")
plt.show()

# %%
print("DBSCAN Performance:")
print("Epsilon: 1.5")
print("Min Samples: 15")
print("Number of Clusters: 12")
valid_labels = final_df['dbscan_labels'] != -1
if valid_labels.any():
    score = silhouette_score(final_df[valid_labels], dbscan_labels[valid_labels])
    print("\nDBSCAN Silhouette Score:", score)
else:
    print("\nNo valid clusters found by DBSCAN.")


db_score = davies_bouldin_score(final_df[valid_labels],dbscan_labels[valid_labels])
ch_score = calinski_harabasz_score(final_df[valid_labels], dbscan_labels[valid_labels])

print(f"Calinski-Harabasz Score: {ch_score}")
print(f"Davies-Bouldin Score: {db_score}")
# Out:
# DBSCAN Performance:
# Epsilon: 1.5
# Min Samples: 15
# Number of Clusters: 12
#
# DBSCAN Silhouette Score: 0.6483354544579168
# Calinski-Harabasz Score: 8195.954617422814
# Davies-Bouldin Score: 0.4808604470263315

# %%
features = ['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7']
cluster_labels = sorted(label for label in final_df['dbscan_labels'].unique() if label != -1)

colors = plt.cm.tab10(np.linspace(0, 1, len(cluster_labels)))
n_clusters = len(cluster_labels)

fig, axes = plt.subplots(
    nrows=int(np.ceil(n_clusters / 3)), ncols=3,
    figsize=(18, 12), subplot_kw=dict(polar=True)
)

axes = axes.flatten()

for idx, (cluster_label, color) in enumerate(zip(cluster_labels, colors)):
    cluster_data = final_df[final_df['dbscan_labels'] == cluster_label][features].mean()
    values = cluster_data.tolist()
    values += values[:1]
    angles = np.linspace(0, 2 * np.pi, len(features), endpoint=False).tolist()
    angles += angles[:1]

    ax = axes[idx]
    ax.fill(angles, values, color=color, alpha=0.25)
    ax.plot(angles, values, color=color, linewidth=2)
    ax.set_yticks([])
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(features, fontsize=10)
    ax.set_title(f"Cluster {cluster_label}", fontsize=14, pad=20)

for ax in axes[len(cluster_labels):]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# Each cluster has a unique profile based on principal component (PC) values, showing distinct user groups with different characteristics. Some clusters are defined by specific PCs (e.g., Cluster 1 by PC2, Cluster 3 by PC4), while others share patterns across PCs (e.g., Clusters 0 and 8 both emphasize PC2 and PC3). These profiles can help in targeted marketing, personalized recommendations, and user segmentation by tailoring content to match each group's characteristics. Further analysis could clarify the meaning of each PC, enhancing the model's interpretability and application.

# %% [markdown]
# ## Cluster Analysis

# %%
eda_df['dbscan_labels'] = dbscan_labels
eda_df.head()
# Out:
#                                                                                                      danceability  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                          0.680455
# Saudade De Bahia                               ... Antônio Carlos Jobim                                  0.767322
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                      0.880041
# Mulher Eu Sei                                  ... Chico César                                           0.729059
# Rosa Morena                                    ... Kurt Elling                                           0.673216
#
#                                                                                                      mode  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                       0.0
# Saudade De Bahia                               ... Antônio Carlos Jobim                               1.0
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                   1.0
# Mulher Eu Sei                                  ... Chico César                                        1.0
# Rosa Morena                                    ... Kurt Elling                                        1.0
#
#                                                                                                      acousticness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                          0.696787
# Saudade De Bahia                               ... Antônio Carlos Jobim                                  0.217871
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                      0.454819
# Mulher Eu Sei                                  ... Chico César                                           0.882530
# Rosa Morena                                    ... Kurt Elling                                           0.919679
#
#                                                                                                      instrumentalness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                              0.000060
# Saudade De Bahia                               ... Antônio Carlos Jobim                                      0.000002
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                          0.000064
# Mulher Eu Sei                                  ... Chico César                                               0.000041
# Rosa Morena                                    ... Kurt Elling                                               0.000348
#
#                                                                                                      energy  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      0.2590
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.3990
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                  0.7300
# Mulher Eu Sei                                  ... Chico César                                       0.0502
# Rosa Morena                                    ... Kurt Elling                                       0.1190
#
#                                                                                                       valence  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      0.310660
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.703553
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                  0.918782
# Mulher Eu Sei                                  ... Chico César                                       0.531980
# Rosa Morena                                    ... Kurt Elling                                       0.408122
#
#                                                                                                         tempo  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                     -0.232633
# Saudade De Bahia                               ... Antônio Carlos Jobim                              0.154816
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.673325
# Mulher Eu Sei                                  ... Chico César                                      -0.327071
# Rosa Morena                                    ... Kurt Elling                                       0.046532
#
#                                                                                                      liveness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                      5.882353
# Saudade De Bahia                               ... Antônio Carlos Jobim                             -0.124567
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.006920
# Mulher Eu Sei                                  ... Chico César                                       1.806228
# Rosa Morena                                    ... Kurt Elling                                      -0.145329
#
#                                                                                                      loudness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                     -0.955541
# Saudade De Bahia                               ... Antônio Carlos Jobim                             -0.874033
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                 -0.610901
# Mulher Eu Sei                                  ... Chico César                                      -1.774576
# Rosa Morena                                    ... Kurt Elling                                      -2.053186
#
#                                                                                                      time_signature  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                                 0.0
# Saudade De Bahia                               ... Antônio Carlos Jobim                                         0.0
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                             0.0
# Mulher Eu Sei                                  ... Chico César                                                  0.0
# Rosa Morena                                    ... Kurt Elling                                                  0.0
#
#                                                                                                      speechiness  \
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                         0.246438
# Saudade De Bahia                               ... Antônio Carlos Jobim                                -0.355407
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                     4.881811
# Mulher Eu Sei                                  ... Chico César                                         -0.145851
# Rosa Morena                                    ... Kurt Elling                                         -0.298407
#
#                                                                                                      dbscan_labels
# name                                               artist
# Se Eu Quiser Falar Com Deus                    ... Gilberto Gil                                                  8
# Saudade De Bahia                               ... Antônio Carlos Jobim                                          0
# Canta Canta, Minha Gente                       ... Martinho Da Vila                                              1
# Mulher Eu Sei                                  ... Chico César                                                   2
# Rosa Morena                                    ... Kurt Elling                                                   0

# %%
for i in range(12):
    print('Cluster:', i)
    display(eda_df[eda_df['dbscan_labels'] == i].describe())
    print('\n')
    eda_df['dbscan_labels']
# Out:
# Cluster: 0
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    314.000000  314.000000    314.000000        314.000000  314.000000
# mean       0.468580    0.671975      0.760937          0.498969    0.250587
# std        0.182929    0.470244      0.312132          0.419282    0.194478
# min        0.083454    0.000000      0.000001          0.000000    0.012100
# 25%        0.329886    0.000000      0.663153          0.001388    0.116500
# 50%        0.468459    1.000000      0.912149          0.660406    0.194000
# 75%        0.591779    1.000000      0.979418          0.911675    0.321750
# max        0.964840    1.000000      0.998996          0.992893    0.964000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  314.000000  314.000000  314.000000  314.000000      314.000000
# mean     0.322401    0.398998    0.012507   -1.537548       -0.159236
# std      0.243199    0.474282    0.387752    0.472766        0.415507
# min      0.022437   -0.435143   -0.633218   -2.691421       -1.000000
# 25%      0.128173    0.111197   -0.187370   -1.901943        0.000000
# 50%      0.257868    0.303237   -0.096886   -1.565207        0.000000
# 75%      0.462944    0.553759    0.069204   -1.152890        0.000000
# max      1.000000    2.214374    2.069204   -0.485757        1.000000
#
#        speechiness  dbscan_labels
# count   314.000000          314.0
# mean     -0.150955            0.0
# std       0.277139            0.0
# min      -0.496228            0.0
# 25%      -0.338642            0.0
# 50%      -0.222967            0.0
# 75%      -0.061190            0.0
# max       1.713328            0.0
# Cluster: 1
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    165.000000  165.000000    165.000000        165.000000  165.000000
# mean       0.668779    0.587879      0.135448          0.078372    0.734473
# std        0.235938    0.493715      0.167143          0.232793    0.173718
# min        0.124095    0.000000      0.000002          0.000000    0.215000
# 25%        0.519131    0.000000      0.016165          0.000000    0.620000
# 50%        0.748707    1.000000      0.060341          0.000000    0.730000
# 75%        0.844881    1.000000      0.188755          0.001157    0.862000
# max        0.971044    1.000000      0.664659          0.963452    0.998000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  165.000000  165.000000  165.000000  165.000000      165.000000
# mean     0.536776   -0.072812    0.223278    0.157821       -0.012121
# std      0.273359    0.881492    0.685251    0.459669        0.220528
# min      0.032386   -1.295759   -0.698962   -1.372139       -1.000000
# 25%      0.323858   -0.690871   -0.290657   -0.010374        0.000000
# 50%      0.618274   -0.499379    0.027682    0.249300        0.000000
# 75%      0.763452    0.549108    0.539792    0.443438        0.000000
# max      0.977665    2.234007    2.553633    1.182282        1.000000
#
#        speechiness  dbscan_labels
# count   165.000000          165.0
# mean      3.874927            1.0
# std       0.531922            0.0
# min       3.104778            1.0
# 25%       3.456832            1.0
# 50%       3.741827            1.0
# 75%       4.261526            1.0
# max       5.435038            1.0
# Cluster: 2
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    461.000000  461.000000    461.000000        461.000000  461.000000
# mean       0.456834    0.689805      0.659640          0.374188    0.347600
# std        0.204601    0.463076      0.358014          0.413352    0.235045
# min        0.068149    0.000000      0.000000          0.000000    0.030400
# 25%        0.274043    0.000000      0.411647          0.000120    0.168000
# 50%        0.459152    1.000000      0.825301          0.085888    0.286000
# 75%        0.613237    1.000000      0.945783          0.870051    0.462000
# max        0.962771    1.000000      0.997992          0.975635    0.985000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  461.000000  461.000000  461.000000  461.000000      461.000000
# mean     0.367433   -0.715559    0.125596   -1.196663       -0.078091
# std      0.264074    0.374083    0.482280    0.445900        0.382181
# min      0.031675   -1.634773   -0.662976   -2.389429       -1.000000
# 25%      0.140102   -1.016171   -0.180623   -1.519019        0.000000
# 50%      0.307614   -0.718827   -0.034602   -1.096163        0.000000
# 75%      0.559391   -0.420478    0.325260   -0.855755        0.000000
# max      0.993909    0.158171    1.806228   -0.259839        1.000000
#
#        speechiness  dbscan_labels
# count   461.000000          461.0
# mean     -0.131879            2.0
# std       0.331753            0.0
# min      -0.504610            2.0
# 25%      -0.358759            2.0
# 50%      -0.236379            2.0
# 75%      -0.025147            2.0
# max       1.327745            2.0
# Cluster: 3
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    896.000000  896.000000    896.000000        896.000000  896.000000
# mean       0.421659    0.715402      0.151213          0.338376    0.792568
# std        0.202808    0.451475      0.255580          0.394676    0.194823
# min        0.067011    0.000000      0.000000          0.000000    0.102000
# 25%        0.248190    0.000000      0.000031          0.000005    0.677000
# 50%        0.382110    1.000000      0.004548          0.051777    0.865500
# 75%        0.584281    1.000000      0.187249          0.811675    0.945000
# max        0.935884    1.000000      0.994980          0.983756    0.999000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  896.000000  896.000000  896.000000  896.000000      896.000000
# mean     0.437549    0.810909    0.493480   -0.056481       -0.087054
# std      0.277112    0.707244    0.795971    0.482687        0.312156
# min      0.030863   -1.167816   -0.789619   -1.975795       -1.000000
# 25%      0.209137    0.457511   -0.166090   -0.363741        0.000000
# 50%      0.376142    0.867274    0.211073    0.001400        0.000000
# 75%      0.660914    1.367876    1.162630    0.277540        0.000000
# max      1.000000    2.505219    2.636678    1.338054        1.000000
#
#        speechiness  dbscan_labels
# count   896.000000          896.0
# mean      0.392968            3.0
# std       0.573253            0.0
# min      -0.531433            3.0
# 25%      -0.074183            3.0
# 50%       0.360436            3.0
# 75%       0.757754            3.0
# max       2.518022            3.0
# Cluster: 4
#        danceability    mode  acousticness  instrumentalness       energy  \
# count   1028.000000  1028.0   1028.000000       1028.000000  1028.000000
# mean       0.619478     1.0      0.193132          0.113350     0.713654
# std        0.183248     0.0      0.243670          0.261191     0.172115
# min        0.122027     1.0      0.000000          0.000000     0.189000
# 25%        0.525336     1.0      0.007199          0.000000     0.586000
# 50%        0.650465     1.0      0.085040          0.000036     0.737500
# 75%        0.753878     1.0      0.298695          0.014619     0.857000
# max        0.994829     1.0      0.964859          0.986802     0.992000
#
#            valence        tempo     liveness     loudness  time_signature  \
# count  1028.000000  1028.000000  1028.000000  1028.000000     1028.000000
# mean      0.554279    -0.203564    -0.085684     0.094423       -0.018482
# std       0.261291     0.449794     0.318701     0.377851        0.208507
# min       0.031675    -1.598467    -0.727336    -0.816236       -1.000000
# 25%       0.335025    -0.584133    -0.317820    -0.174255        0.000000
# 50%       0.559391    -0.140798    -0.145329     0.109666        0.000000
# 75%       0.777665     0.179713     0.117647     0.379055        0.000000
# max       0.992893     0.709024     0.906574     1.397332        1.000000
#
#        speechiness  dbscan_labels
# count  1028.000000         1028.0
# mean     -0.095905            4.0
# std       0.354927            0.0
# min      -0.553227            4.0
# 25%      -0.377200            4.0
# 50%      -0.209556            4.0
# 75%       0.115675            4.0
# max       0.975692            4.0
# Cluster: 5
#        danceability         mode  acousticness  instrumentalness       energy  \
# count   1244.000000  1244.000000   1244.000000       1244.000000  1244.000000
# mean       0.571303     0.320740      0.126582          0.202602     0.797536
# std        0.243631     0.466949      0.202157          0.331386     0.168186
# min        0.063702     0.000000      0.000000          0.000000     0.205000
# 25%        0.314374     0.000000      0.000163          0.000000     0.684750
# 50%        0.631851     0.000000      0.025251          0.001049     0.834500
# 75%        0.777663     1.000000      0.175954          0.296701     0.948000
# max        1.000000     1.000000      0.986948          0.970558     0.999000
#
#            valence        tempo     liveness     loudness  time_signature  \
# count  1244.000000  1244.000000  1244.000000  1244.000000     1244.000000
# mean      0.454022    -0.176823     0.078561     0.164456       -0.044212
# std       0.279861     0.564040     0.525801     0.397068        0.231419
# min       0.030761    -1.753891    -0.703114    -1.330973       -1.000000
# 25%       0.188832    -0.618543    -0.284948    -0.070105        0.000000
# 50%       0.437056    -0.188810    -0.069204     0.231681        0.000000
# 75%       0.690355     0.214810     0.325260     0.438828        0.000000
# max       0.990863     2.136108     2.664360     1.429277        1.000000
#
#        speechiness  dbscan_labels
# count  1244.000000         1244.0
# mean      0.924600            5.0
# std       1.021232            0.0
# min      -0.544845            5.0
# 25%      -0.060352            5.0
# 50%       0.942163            5.0
# 75%       1.730092            5.0
# max       3.188600            5.0
# Cluster: 6
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    489.000000  489.000000    489.000000        489.000000  489.000000
# mean       0.624530    0.625767      0.174037          0.076692    0.765166
# std        0.160887    0.484420      0.233334          0.210361    0.158374
# min        0.117890    0.000000      0.000001          0.000000    0.112000
# 25%        0.532575    0.000000      0.008163          0.000000    0.673000
# 50%        0.645295    1.000000      0.061647          0.000018    0.798000
# 75%        0.743537    1.000000      0.251004          0.006386    0.885000
# max        0.968976    1.000000      0.978916          0.960406    0.993000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  489.000000  489.000000  489.000000  489.000000      489.000000
# mean     0.581745    0.019509    1.486276    0.212693       -0.016360
# std      0.239369    0.532862    0.456529    0.399663        0.155955
# min      0.062741   -1.451367    0.692042   -1.048576       -1.000000
# 25%      0.390863   -0.374501    1.148789   -0.031121        0.000000
# 50%      0.579695    0.127784    1.432526    0.262309        0.000000
# 75%      0.771574    0.294913    1.743945    0.491849        0.000000
# max      0.993909    1.721971    2.809689    1.120534        1.000000
#
#        speechiness  dbscan_labels
# count   489.000000          489.0
# mean     -0.085732            6.0
# std       0.318461            0.0
# min      -0.556580            6.0
# 25%      -0.326907            6.0
# 50%      -0.165968            6.0
# 75%       0.078793            6.0
# max       1.009220            6.0
# Cluster: 7
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    205.000000  205.000000    205.000000        205.000000  205.000000
# mean       0.266120    0.634146      0.952380          0.811010    0.062168
# std        0.137629    0.482848      0.087772          0.247382    0.068636
# min        0.061634    0.000000      0.130522          0.000001    0.000020
# 25%        0.145812    0.000000      0.940763          0.825381    0.013200
# 50%        0.257497    1.000000      0.985944          0.915736    0.045200
# 75%        0.362978    1.000000      0.995984          0.938071    0.079200
# max        0.673216    1.000000      1.000000          1.000000    0.537000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  205.000000  205.000000  205.000000  205.000000      205.000000
# mean     0.115905   -1.114274   -0.093149   -3.251299       -0.312195
# std      0.118660    0.328457    0.390016    0.956243        0.524028
# min      0.019898   -2.228141   -0.525952   -6.103738       -1.000000
# 25%      0.038680   -1.325327   -0.271972   -3.796806       -1.000000
# 50%      0.073198   -1.170273   -0.184083   -2.971019        0.000000
# 75%      0.148223   -0.942212   -0.089965   -2.468961        0.000000
# max      0.824365   -0.300806    1.993080   -2.002635        1.000000
#
#        speechiness  dbscan_labels
# count   205.000000          205.0
# mean     -0.177450            7.0
# std       0.196403            0.0
# min      -0.476111            7.0
# 25%      -0.286672            7.0
# 50%      -0.226320            7.0
# 75%      -0.135792            7.0
# max       0.791282            7.0
# Cluster: 8
#        danceability        mode  acousticness  instrumentalness      energy  \
# count    173.000000  173.000000    173.000000        173.000000  173.000000
# mean       0.531103    0.624277      0.260932          0.169527    0.731512
# std        0.181301    0.485715      0.320619          0.314745    0.244673
# min        0.097001    0.000000      0.000002          0.000000    0.062200
# 25%        0.402275    0.000000      0.004177          0.000000    0.625000
# 50%        0.562565    1.000000      0.057028          0.000141    0.815000
# 75%        0.671148    1.000000      0.489960          0.104569    0.920000
# max        0.891417    1.000000      0.988956          0.959391    1.000000
#
#           valence       tempo    liveness    loudness  time_signature  \
# count  173.000000  173.000000  173.000000  173.000000      173.000000
# mean     0.463357    0.008374    3.917355   -0.050443       -0.034682
# std      0.267530    0.644384    0.832851    0.746810        0.261835
# min      0.031472   -1.256599    2.615917   -2.649267       -1.000000
# 25%      0.251777   -0.479509    3.259516   -0.325704        0.000000
# 50%      0.441624    0.141313    3.806228    0.135518        0.000000
# 75%      0.690355    0.285797    4.256055    0.470278        0.000000
# max      0.984772    2.069468    5.965398    0.990120        1.000000
#
#        speechiness  dbscan_labels
# count   173.000000          173.0
# mean      0.244461            8.0
# std       0.566592            0.0
# min      -0.479464            8.0
# 25%      -0.211232            8.0
# 50%       0.112322            8.0
# 75%       0.569992            8.0
# max       1.813915            8.0
# Cluster: 9
#        danceability       mode  acousticness  instrumentalness     energy  \
# count     41.000000  41.000000     41.000000         41.000000  41.000000
# mean       0.610513   0.585366      0.145584          0.043456   0.769902
# std        0.181363   0.498779      0.148409          0.176031   0.154467
# min        0.205791   0.000000      0.000107          0.000000   0.425000
# 25%        0.502585   0.000000      0.016968          0.000000   0.706000
# 50%        0.627715   1.000000      0.129518          0.000004   0.787000
# 75%        0.724922   1.000000      0.189759          0.000170   0.899000
# max        0.991727   1.000000      0.535141          0.848731   0.989000
#
#          valence      tempo   liveness   loudness  time_signature  \
# count  41.000000  41.000000  41.000000  41.000000            41.0
# mean    0.503922   0.907360  -0.013453   0.222946             0.0
# std     0.264342   0.803789   0.489445   0.371744             0.0
# min     0.038782  -0.607953  -0.570242  -0.597234             0.0
# 25%     0.353299   0.181345  -0.292042  -0.006587             0.0
# 50%     0.570558   1.342344  -0.131488   0.313190             0.0
# 75%     0.730964   1.582138   0.027682   0.530216             0.0
# max     0.914721   2.183115   1.598616   0.701136             0.0
#
#        speechiness  dbscan_labels
# count    41.000000           41.0
# mean      5.551162            9.0
# std       0.578609            0.0
# min       4.680637            9.0
# 25%       5.116513            9.0
# 50%       5.451802            9.0
# 75%       5.820620            9.0
# max       6.826488            9.0
# Cluster: 10
#        danceability       mode  acousticness  instrumentalness     energy  \
# count     16.000000  16.000000     16.000000         16.000000  16.000000
# mean       0.618149   0.187500      0.114424          0.054335   0.845375
# std        0.175826   0.403113      0.137678          0.156286   0.120100
# min        0.179938   0.000000      0.000002          0.000000   0.610000
# 25%        0.528438   0.000000      0.015379          0.000000   0.777250
# 50%        0.678387   0.000000      0.048795          0.000005   0.896000
# 75%        0.732161   0.000000      0.190261          0.006282   0.920500
# max        0.797311   1.000000      0.445783          0.619289   0.995000
#
#          valence      tempo   liveness   loudness  time_signature  \
# count  16.000000  16.000000  16.000000  16.000000            16.0
# mean    0.476472   0.086658   3.813581   0.273907             0.0
# std     0.237932   0.621525   0.630426   0.329298             0.0
# min     0.039797  -0.921284   2.768166  -0.650914             0.0
# 25%     0.346447  -0.238651   3.330450   0.125638             0.0
# 50%     0.505076   0.178689   3.795848   0.333855             0.0
# 75%     0.593909   0.262049   4.297578   0.451589             0.0
# max     0.824365   1.383723   4.837370   0.689610             0.0
#
#        speechiness  dbscan_labels
# count    16.000000           16.0
# mean      2.690905           10.0
# std       0.531787            0.0
# min       1.931266           10.0
# 25%       2.249790           10.0
# 50%       2.719195           10.0
# 75%       2.903604           10.0
# max       3.725063           10.0
# Cluster: 11
#        danceability       mode  acousticness  instrumentalness     energy  \
# count     89.000000  89.000000     89.000000         89.000000  89.000000
# mean       0.334929   0.561798      0.952168          0.842101   0.061846
# std        0.130286   0.498978      0.104100          0.237835   0.058615
# min        0.143744   0.000000      0.280120          0.002437   0.002360
# 25%        0.206825   0.000000      0.961847          0.869036   0.021200
# 50%        0.335057   1.000000      0.989960          0.921827   0.046000
# 75%        0.435367   1.000000      0.996988          0.948223   0.083200
# max        0.619442   1.000000      1.000000          0.992893   0.362000
#
#          valence      tempo   liveness   loudness  time_signature  \
# count  89.000000  89.000000  89.000000  89.000000       89.000000
# mean    0.167530   0.481913  -0.078986  -3.278597       -0.292135
# std     0.140554   0.482719   0.351488   0.689618        0.526615
# min     0.032893  -0.251500  -0.505190  -5.726824       -1.000000
# 25%     0.049340   0.135500  -0.238062  -3.757286       -1.000000
# 50%     0.110660   0.443467  -0.159170  -3.145562        0.000000
# 75%     0.274112   0.695970  -0.062284  -2.761568        0.000000
# max     0.563452   1.608561   1.356401  -2.247489        1.000000
#
#        speechiness  dbscan_labels
# count    89.000000           89.0
# mean     -0.174407           11.0
# std       0.153004            0.0
# min      -0.432523           11.0
# 25%      -0.268231           11.0
# 50%      -0.212909           11.0
# 75%      -0.129086           11.0
# max       0.395641           11.0

# %%
def plot_violin_filtered(data, label_col, num_cols, nrows=1, figsize=(16, 70)):

    data = data[data[label_col] != -1]

    fig, axs = plt.subplots(nrows=nrows, ncols=1, figsize=figsize)

    if nrows == 1:
        axs = [axs]

    for i, col in enumerate(num_cols):
        q1, q3 = np.quantile(data[col].dropna(), [0.25, 0.75])
        upper_bound = q3 + 1.5 * (q3 - q1)

        filtered_data = data.loc[data[col] <= upper_bound, [label_col, col]].dropna()

        if not filtered_data.empty:
            sns.violinplot(data=filtered_data, x=label_col, y=col, ax=axs[i])
        else:
            axs[i].text(0.5, 0.5, f'No Data for {col}',
                        horizontalalignment='center', verticalalignment='center', transform=axs[i].transAxes)
            axs[i].set_title(f"No valid data for {col}")

    plt.tight_layout()
    plt.show()

# %%
num_columns = eda_df.columns.drop('dbscan_labels')
plot_violin_filtered(eda_df, 'dbscan_labels', num_columns, nrows=len(num_columns), figsize=(16, 70))

# %% [markdown]
# ## Cluster Analysis

# %% [markdown]
# From the above Graphs we observe clusters formed has unique features and each of them are suitable for particular ocassions for example
#
# Cluster 2: It has High danceability, energy, and positivity; low acousticness.
# Perfect for upbeat party playlists.
#
# Cluster 4: has High acousticness, low energy, and neutral mood.
# Great for mellow, acoustic-focused playlists.
#
# Cluster 6: High acousticness, low energy, and sad mood.
# Ideal for emotional or reflective acoustic playlists.
#
# Cluster 11: High danceability, energy, and positivity; low acousticness.
# Perfect for high-energy dance playlists.
#
# Cluster 9: Mellow, less danceable, mixed acousticness, and sad mood.
# Good for introspective or calming playlists.

# %% [markdown]
# ### INSIGTHS

# %% [markdown]
#  1.) Clustering algorithms (K-Means, DBSCAN, Agglomerative) revealed distinct groups of songs with shared audio characteristics.
#
# 2.) PCA helped reduce the complexity of the feature space, making it easier to visualize and interpret the clusters, enhancing the understanding of song groupings based on audio features.
#
# 3.)  Min-Max scaling normalized the features to a fixed range (0 to 1), making algorithms like K-Means more effective by ensuring all features contributed equally. This likely improved the cohesion and separation of clusters.

# %% [markdown]
# ### Further scope

# %% [markdown]
# Clustering for song recommendations can be further enhanced by incorporating a wide range of audio and contextual features, such as tempo, rhythm, mood, lyrics, and even metadata like artist collaborations or release year. By grouping songs into clusters based on these attributes, the system can recommend tracks that align with a user’s listening preferences while also introducing diverse options from less explored clusters. Additionally, clustering can adapt dynamically to trends, enabling recommendations that reflect both individual tastes and evolving popular patterns, ensuring a more personalized and engaging music discovery experience.

# %% [markdown]
# ### Refrences

# %% [markdown]
# https://iieta.org/journals/ria/paper/10.18280/ria.380138
#
# Hands on ML
#
# https://scikit-learn.org/stable/

# %% [markdown]
# ### Pseduo Code

# %% [markdown]
# Algorithm K-Means Clustering:
#
# 1. Initialize centroids
#    - Randomly select k data points from the dataset as initial centroids.
#
# 2. Repeat until convergence:
#    a. Assignment step:
#       - For each data point in the dataset:
#         i.  Calculate the distance between the data point and each centroid.
#         ii. Assign the data point to the nearest centroid.
#
#    b. Update step:
#       - For each centroid:
#         i.  Calculate the new centroid by taking the mean of all data points assigned to it.
#
# 3. Convergence criteria:
#    - Check if the centroids have stopped moving (i.e., the changes in centroid positions are below a certain threshold).
#    - If centroids have converged, terminate the algorithm.
#    - If not, repeat steps 2a and 2b.
#
# End Algorithm

# %% [markdown]
# ## Agglomerative Clustering

# %% [markdown]
# given a dataset (d1, d2, d3, ....dN) of size N
#
#  compute the distance matrix
# for i=1 to N:
#
#    as the distance matrix is symmetric about
#    the primary diagonal so we compute only lower
#    part of the primary diagonal
#
#    for j=1 to i:
#       dis_mat[i][j] = distance[di, dj]
#
# each data point is a singleton cluster
# repeat
#    merge the two cluster having minimum distance
#    update the distance matrix
# until only a single cluster remains

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# DBSCAN(dataset, eps, MinPts){
# cluster index
# C = 1
# for each unvisited point p in dataset {
#          mark p as visited
#          # find neighbors
#          Neighbors N = find the neighboring points of p
#
#          if |N|>=MinPts:
#              N = N U N'
#              if p' is not a member of any cluster:
#                  add p' to cluster C
# }
